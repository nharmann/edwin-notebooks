# %% [markdown]
# # MACHINE LEARNING

# %% [markdown]
# ## Cardiovascular Disease Diagnosis

# %% [markdown]
# #### Description: This program classifies a persin as having cardiovascular disease or not
# #### Created on Sun May 16 23:16:34 2021
# #### @author: Edwin Nyakan

# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
# Load data
df = pd.read_csv('D:\CTIED\Training\Machine Learning\Python\cardio_train.csv')

# Print the first 7 rows of the data
df.head(7)

# %%
# Get the shape of the data
df.shape

# %%
#Looking for missing values 
df.isnull().values.any()

# %%
#Count missing values in each variable
df.isna().sum()

# %%
# View some basic statistics
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
# Count of number of individuals with and without cardiovascular disease
df['cardio'].value_counts()
# Out:
# 0    35021
# 1    34979
# Name: cardio, dtype: int64

# %%
# Visualize the count
sns.countplot(df['cardio'])
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cardio', ylabel='count'>

# %%
# Let's create year variable
df['years'] =(df['age']/365).round(0)
df['years'] =pd.to_numeric(df['years'],downcast='integer')

# %%
#Visualize the data
sns.countplot(x='years', hue='cardio', data=df, palette='colorblind', edgecolor=sns.color_palette('dark', n_colors=1))
# Out:
# <AxesSubplot:xlabel='years', ylabel='count'>

# %%
# Get the correlation of the variables
df.corr()
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003457  0.003502 -0.003038 -0.001830  0.003356
# age          0.003457  1.000000 -0.022811 -0.081515  0.053684  0.020764
# gender       0.003502 -0.022811  1.000000  0.499033  0.155406  0.006005
# height      -0.003038 -0.081515  0.499033  1.000000  0.290968  0.005488
# weight      -0.001830  0.053684  0.155406  0.290968  1.000000  0.030702
# ap_hi        0.003356  0.020764  0.006005  0.005488  0.030702  1.000000
# ap_lo       -0.002529  0.017647  0.015254  0.006150  0.043710  0.016086
# cholesterol  0.006106  0.154424 -0.035821 -0.050226  0.141768  0.023778
# gluc         0.002467  0.098703 -0.020491 -0.018595  0.106857  0.011841
# smoke       -0.003699 -0.047633  0.338135  0.187989  0.067780 -0.000922
# alco         0.001210 -0.029723  0.170966  0.094419  0.067113  0.001408
# active       0.003755 -0.009927  0.005866 -0.006570 -0.016867 -0.000033
# ...

# %%
#Visualize the correlation matrix
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#Increase the figure size of the correlation matrix
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, fmt='.0%')
# Out:
# <AxesSubplot:>

# %%
#Remove years and id variables
df = df.drop('years', axis = 1)
df =df.drop('id', axis = 1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-6e39bb11dd74> in <module>
#       1 #Remove years and id variables
# ----> 2 df = df.drop('years', axis = 1)
#       3 df =df.drop('id', axis = 1)
#       4 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %% [markdown]
# ### Creating diagnotic model

# %%
# Split the data into feature and target data set (i.e independent and dependent data set)
X = df.iloc[:,:-1].values
Y = df.iloc[:,-1].values

# %%
# Split the data again, into 75% training data set and 25% testing data set
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.25, random_state=1)

# %%
# Feature scaling : Scale the values in the data to be values between 0 and 1 inclusive
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Use Random Forest Classifier
from sklearn import ensemble 
forest = ensemble.RandomForestClassifier(n_estimators = 100, criterion = 'entropy', random_state=1)
forest.fit(X_train, Y_train)
forest.score(X_test, Y_test)
# Out:
# 0.7204571428571429

# %%
# Test the model
model = forest
model.score(X_train, Y_train)
# Out:
# 0.9997904761904762

# %%
#Validating the model
from sklearn.metrics import confusion_matrix
cm = confusion_matrix (Y_test, model.predict(X_test))
TN =cm[0][0]
TP =cm[1][1]
FN =cm[1][0]
FP =cm[0][1]

# Print the confusion matrix
print(cm)

print()

# Print accuracy of the model on the test data
print('Model Test Accuracy = {}'.format((TP+TN)/(TP+TN+FN+FP)))
# Out:
# [[6369 2240]
#  [2652 6239]]
#
# Model Test Accuracy = 0.7204571428571429
